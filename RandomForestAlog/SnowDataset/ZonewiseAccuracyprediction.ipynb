# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score 
from sklearn.metrics import roc_auc_score
from sklearn import metrics
from sklearn import linear_model, tree, ensemble
from sklearn.model_selection import cross_validate
# %matplotlib inline

# %%
Dataset = 'FinalCompleteDatasetwithLocationUpdated.csv'
df = pd.read_csv(Dataset)

# %%
df.head()
# Out:
#    Location Region  SnowDepth  Class          X          Y  \
# 0         1    SR1         30      4  65.061403  25.479150
# 1         2    SR1         35      5  65.061446  25.478976
# 2         3    SR1         39      6  65.061393  25.479098
# 3         4    SR1         17      2  65.061397  25.479207
# 4         5    SR1         13      1  65.061179  25.479134
#
#                              Coordinates  Snowvolume  Snowweight  \
# 0          65.061403475,25.4791502965053     9702.60         435
# 1          65.061446009,25.4789757112956    11319.70         618
# 2            65.0613925,25.4790982528733    12613.38         752
# 3            65.0613972,25.4792070106939     5498.14         325
# 4  65.06117902006007, 25.479133551302514     4204.46         250
#
#    AveMaxpressure  AveMinpressure  Ave. Mean pressure  AvergaeTempnearSurface  \
# 0           22.77            1.86            3.310000               15.430000
# ...

# %%
Zone1 = df[df['Region'] == 'SR1']
Zone2 = df[df['Region'] == 'SR2']
Zone3 = df[df['Region'] == 'SR3']
Zone4 = df[df['Region'] == 'SR4']

# %%
Zone1.head()
# Out:
#    Location Region  SnowDepth  Class          X          Y  \
# 0         1    SR1         30      4  65.061403  25.479150
# 1         2    SR1         35      5  65.061446  25.478976
# 2         3    SR1         39      6  65.061393  25.479098
# 3         4    SR1         17      2  65.061397  25.479207
# 4         5    SR1         13      1  65.061179  25.479134
#
#                              Coordinates  Snowvolume  Snowweight  \
# 0          65.061403475,25.4791502965053     9702.60         435
# 1          65.061446009,25.4789757112956    11319.70         618
# 2            65.0613925,25.4790982528733    12613.38         752
# 3            65.0613972,25.4792070106939     5498.14         325
# 4  65.06117902006007, 25.479133551302514     4204.46         250
#
#    AveMaxpressure  AveMinpressure  Ave. Mean pressure  AvergaeTempnearSurface  \
# 0           22.77            1.86            3.310000               15.430000
# ...

# %%
Zone1
# Out:
#     Location Region  SnowDepth  Class          X          Y  \
# 0          1    SR1         30      4  65.061403  25.479150
# 1          2    SR1         35      5  65.061446  25.478976
# 2          3    SR1         39      6  65.061393  25.479098
# 3          4    SR1         17      2  65.061397  25.479207
# 4          5    SR1         13      1  65.061179  25.479134
# 5          6    SR1         37      6  65.061183  25.479197
# 6          7    SR1         40      6  65.061462  25.479423
# 7          8    SR1         27      4  65.061412  25.479359
# 8          9    SR1         28      4  65.061370  25.479375
# 9         10    SR1         27      4  65.061286  25.479364
# 10        11    SR1         13      1  65.061235  25.479351
# 11        12    SR1         22      3  65.061181  25.479356
# 12        13    SR1         28      4  65.060880  25.479349
# 13        14    SR1         19      2  65.061061  25.479982
# 14        15    SR1         24      3  65.060895  25.479691
# ...

# %%
X = Zone1[['AveMaxpressure','AveMinpressure']]
#Zone1.drop(['Location','Region', 'SnowDepth', 'Class','X','Y','Coordinates','Snowvolume','Snowweight'], axis = 1)

# %%
X
# Out:
#     AveMaxpressure  AveMinpressure
# 0            22.77            1.86
# 1            24.34            1.40
# 2            11.35            0.55
# 3            26.12            2.00
# 4            41.22            3.89
# 5            12.97            0.58
# 6            14.01            0.65
# 7            26.96            1.89
# 8            25.84            1.92
# 9            26.96            1.89
# 10           41.22            3.89
# 11           27.31            2.87
# 12           25.84            1.92
# 13           28.53            2.40
# 14           22.23            2.01
# 15           34.50            3.50
# 16           26.96            1.89
# 17           25.84            2.78
# 18           25.84            2.78
# 19           17.92            0.86
# 20           33.30            2.95
# 21           36.30            3.12
# 22           19.69            1.36
# 23           34.50            2.84
# 24           23.43            2.45

# %%
y = Zone1['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier

# instantiate the classifier 

rfc = RandomForestClassifier(random_state=42)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score 

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.4000

# %% [markdown]
# <h1> Zone 2 prediction accuracy </h1>

# %%
X2 = Zone2.drop(['Location','Region', 'SnowDepth', 'Class','X','Y','Coordinates','Snowvolume','Snowweight'], axis = 1)
y2 = Zone2['Class']


X_train, X_test, y_train, y_test = train_test_split(X2, y2, test_size = 0.20, random_state = 42)
rfc = RandomForestClassifier(random_state=42)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score 

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.4000

# %%
X3 = Zone3.drop(['Location','Region', 'SnowDepth', 'Class','X','Y','Coordinates','Snowvolume','Snowweight'], axis = 1)
y3 = Zone3['Class']


X_train, X_test, y_train, y_test = train_test_split(X3, y3, test_size = 0.20, random_state = 42)
rfc = RandomForestClassifier(random_state=42)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score 

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.2500

# %%
X4 = Zone4.drop(['Location','Region', 'SnowDepth', 'Class','X','Y','Coordinates','Snowvolume','Snowweight'], axis = 1)
y4 = Zone4['Class']


X_train, X_test, y_train, y_test = train_test_split(X4, y4, test_size = 0.20, random_state = 42)
rfc = RandomForestClassifier(random_state=42)

# fit the model

rfc.fit(X_train, y_train)

# Predict the Test set results

y_pred = rfc.predict(X_test)

# Check accuracy score 

from sklearn.metrics import accuracy_score

print('Model accuracy score with 10 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 10 decision-trees : 0.5000
